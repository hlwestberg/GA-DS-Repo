# %% [markdown]
# ### Pandas Lab -- Grouping & Merging
#
# Welcome to today's lab!  It will come in two different parts:
#
# One section will be devoted to using the `groupby` method in order to answer different questions about our data.
#
# The second portion will be devoted towards combining grouping & merging to create summary statistics -- one of the more important features you can add to a dataset for statistical modeling.

# %%
#import modules
import pandas as pd
import numpy as np
import plotly.express as px
import datetime as dt

# %%
#load in data sets
base_path = '/Users/hannah.westberg/Projects/GA-DS-Repo/ClassMaterial/Unit1/data/restaurant_data/'
df_reserve = pd.read_csv(base_path+'air_reserve.csv', parse_dates=True)
df_store = pd.read_csv(base_path+'air_store_info.csv')
df_visit = pd.read_csv(base_path+'air_visit_data.csv', parse_dates=True)
df_date= pd.read_csv(base_path+'date_info.csv', parse_dates=True)
df_master= pd.read_csv(base_path+'master.csv')

# %%
df_reserve
# Out:
#        Unnamed: 0          air_store_id  visit_date  reserve_visitors
# 0               0  air_00a91d42b08b08d9  2016-10-31                 2
# 1               1  air_00a91d42b08b08d9  2016-12-05                 9
# 2               2  air_00a91d42b08b08d9  2016-12-14                18
# 3               3  air_00a91d42b08b08d9  2016-12-17                 2
# 4               4  air_00a91d42b08b08d9  2016-12-20                 4
# ...           ...                   ...         ...               ...
# 29825       29825  air_fea5dc9594450608  2017-04-22                 2
# 29826       29826  air_fea5dc9594450608  2017-04-25                 2
# 29827       29827  air_fea5dc9594450608  2017-04-28                 3
# 29828       29828  air_fea5dc9594450608  2017-05-20                 6
# 29829       29829  air_fee8dcf4d619598e  2017-01-09                 5
#
# [29830 rows x 4 columns]

# %%
df_reserve.sort_values(by=['air_store_id', 'visit_date'])
# Out:
#        Unnamed: 0          air_store_id  visit_date  reserve_visitors
# 0               0  air_00a91d42b08b08d9  2016-10-31                 2
# 1               1  air_00a91d42b08b08d9  2016-12-05                 9
# 2               2  air_00a91d42b08b08d9  2016-12-14                18
# 3               3  air_00a91d42b08b08d9  2016-12-17                 2
# 4               4  air_00a91d42b08b08d9  2016-12-20                 4
# ...           ...                   ...         ...               ...
# 29825       29825  air_fea5dc9594450608  2017-04-22                 2
# 29826       29826  air_fea5dc9594450608  2017-04-25                 2
# 29827       29827  air_fea5dc9594450608  2017-04-28                 3
# 29828       29828  air_fea5dc9594450608  2017-05-20                 6
# 29829       29829  air_fee8dcf4d619598e  2017-01-09                 5
#
# [29830 rows x 4 columns]

# %%
# one row per store id and visit date
df_reserve[df_reserve.duplicated(subset=['air_store_id', 'visit_date'])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, air_store_id, visit_date, reserve_visitors]
# Index: []

# %%
df_store
# Out:
#              air_store_id         air_genre_name  \
# 0    air_0f0cdeee6c9bf3d7         Italian/French
# 1    air_7cc17a324ae5c7dc         Italian/French
# 2    air_fee8dcf4d619598e         Italian/French
# 3    air_a17f0778617c76e2         Italian/French
# 4    air_83db5aff8f50478e         Italian/French
# ..                    ...                    ...
# 824  air_9bf595ef095572fb  International cuisine
# 825  air_764f71040a413d4d                  Asian
# 826  air_10bbe8acd943d8f6                  Asian
# 827  air_7514d90009613cd6          Karaoke/Party
# 828  air_c8fe396d6c46275d          Karaoke/Party
#
#                              air_area_name   latitude   longitude
# 0             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853
# 1             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853
# 2             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853
# 3             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853
# 4             Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ..                                     ...        ...         ...
# 824            Tōkyō-to Shibuya-ku Shibuya  35.661777  139.704051
# 825            Tōkyō-to Shibuya-ku Shibuya  35.661777  139.704051
# 826            Tōkyō-to Shibuya-ku Shibuya  35.661777  139.704051
# 827  Hokkaidō Sapporo-shi Minami 3 Jōnishi  43.055460  141.340956
# 828  Hokkaidō Sapporo-shi Minami 3 Jōnishi  43.055460  141.340956
#
# [829 rows x 5 columns]

# %%
# one row per store id
df_store[df_store.duplicated(subset='air_store_id')]
# Out:
# Empty DataFrame
# Columns: [air_store_id, air_genre_name, air_area_name, latitude, longitude]
# Index: []

# %%
df_visit
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
# one row per store and visit date
df_visit[df_visit.duplicated(subset=['air_store_id', 'visit_date'])]
# Out:
# Empty DataFrame
# Columns: [air_store_id, visit_date, visitors]
# Index: []

# %%
df_date
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 1      2016-01-02    Saturday            1
# 2      2016-01-03      Sunday            1
# 3      2016-01-04      Monday            0
# 4      2016-01-05     Tuesday            0
# ..            ...         ...          ...
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0
#
# [517 rows x 3 columns]

# %%
# one row per calendar date
df_date[df_date.duplicated(subset='calendar_date')]
# Out:
# Empty DataFrame
# Columns: [calendar_date, day_of_week, holiday_flg]
# Index: []

# %% [markdown]
# # Join together to recreate the master data set!

# %% [markdown]
# always start with what level of detail you want the final data set to have
# and always check the LOD of the data sets you're using

# %%
df_store_visits = df_visit.merge(df_store, left_on='air_store_id', right_on='air_store_id', how='left')

# %%
df_store_visits.head()
# Out:
#            air_store_id  visit_date  visitors air_genre_name  \
# 0  air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1  air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2  air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3  air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4  air_ba937bf13d40fb24  2016-01-18         6     Dining bar
#
#                   air_area_name   latitude   longitude
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599

# %%
df_store_visits_reserves = df_store_visits.merge(df_reserve, left_on=['air_store_id', 'visit_date'], right_on=['air_store_id', 'visit_date'], how='left')

# %%
df_final = df_store_visits_reserves.merge(df_date, left_on='visit_date', right_on='calendar_date', how='left')

# %%
#check for duplicates
df_final[df_final.duplicated(subset=['air_store_id', 'visit_date'])]
# Out:
# Empty DataFrame
# Columns: [air_store_id, visit_date, visitors, air_genre_name, air_area_name, latitude, longitude, Unnamed: 0, reserve_visitors, calendar_date, day_of_week, holiday_flg]
# Index: []

# %%
df_final.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_final.head()
# Out:
#            air_store_id  visit_date  visitors air_genre_name  \
# 0  air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1  air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2  air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3  air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4  air_ba937bf13d40fb24  2016-01-18         6     Dining bar
#
#                   air_area_name   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-13   Wednesday            0
# 1    2016-01-14    Thursday            0
# 2    2016-01-15      Friday            0
# 3    2016-01-16    Saturday            0
# 4    2016-01-18      Monday            0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252108 entries, 0 to 252107
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   air_store_id      252108 non-null  object
#  1   visit_date        252108 non-null  object
#  2   visitors          252108 non-null  int64
#  3   air_genre_name    252108 non-null  object
#  4   air_area_name     252108 non-null  object
#  5   latitude          252108 non-null  float64
#  6   longitude         252108 non-null  float64
#  7   reserve_visitors  28064 non-null   float64
#  8   calendar_date     252108 non-null  object
#  9   day_of_week       252108 non-null  object
#  10  holiday_flg       252108 non-null  int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 23.1+ MB

# %%
# fix dates
df_final['visit_date'] = pd.to_datetime(df_final['visit_date'])

# %%
df_final['calendar'] = pd.to_datetime(df_final['calendar_date'])

# %%
df_final.describe()
# Out:
#             visitors       latitude      longitude  reserve_visitors  \
# count  252108.000000  252108.000000  252108.000000      28064.000000
# mean       20.973761      35.613121     137.357865         13.751283
# std        16.757007       2.044473       3.671577         17.284799
# min         1.000000      33.211967     130.195555          1.000000
# 25%         9.000000      34.692337     135.341564          5.000000
# 50%        17.000000      35.658068     139.670038         10.000000
# 75%        29.000000      35.694003     139.751599         18.000000
# max       877.000000      44.020632     144.273398       1633.000000
#
#          holiday_flg
# count  252108.000000
# mean        0.050673
# std         0.219329
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df_final['air_area_name'].value_counts()
# Out:
# Fukuoka-ken Fukuoka-shi Daimyō           19775
# Tōkyō-to Shibuya-ku Shibuya              17352
# Tōkyō-to Minato-ku Shibakōen             14696
# Tōkyō-to Shinjuku-ku Kabukichō           12517
# Tōkyō-to Setagaya-ku Setagaya             8719
#                                          ...
# Fukuoka-ken Kitakyūshū-shi Konyamachi      505
# Tōkyō-to Shibuya-ku Higashi                485
# Tōkyō-to Setagaya-ku Kitazawa              484
# Fukuoka-ken Fukuoka-shi Imaizumi           480
# Ōsaka-fu Suita-shi Izumichō                479
# Name: air_area_name, Length: 103, dtype: int64

# %%
df_master['area'].value_counts()
# Out:
# Fukuoka-ken Fukuoka-shi Daimyō           19775
# Tōkyō-to Shibuya-ku Shibuya              17352
# Tōkyō-to Minato-ku Shibakōen             14696
# Tōkyō-to Shinjuku-ku Kabukichō           12517
# Tōkyō-to Setagaya-ku Setagaya             8719
#                                          ...
# Fukuoka-ken Kitakyūshū-shi Konyamachi      505
# Tōkyō-to Shibuya-ku Higashi                485
# Tōkyō-to Setagaya-ku Kitazawa              484
# Fukuoka-ken Fukuoka-shi Imaizumi           480
# Ōsaka-fu Suita-shi Izumichō                479
# Name: area, Length: 103, dtype: int64

# %%
df_master.head()
# Out:
#                      id  visit_date  visitors day_of_week  holiday  \
# 0  air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1  air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2  air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3  air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4  air_ba937bf13d40fb24  2016-01-18         6      Monday        0
#
#         genre                          area   latitude   longitude  \
# 0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# final data set should have one row per restaurant per day
# reservations data-

# %%
# example of only joining certain columns- you can select the columns in the dfs when you use
#use merge

# %% [markdown]
# ### Section I - Grouping

# %%
#group by one column
df_final.groupby('air_store_id').mean()
# Out:
#                        visitors   latitude   longitude  reserve_visitors  \
# air_store_id
# air_00a91d42b08b08d9  26.081897  35.694003  139.753595          5.833333
# air_0164b9927d20bcc3   9.248322  35.658068  139.751599          6.256410
# air_0241aa3964b7f861   9.896465  35.712607  139.779996               NaN
# air_0328696196e46f18   7.939655  34.701279  135.528090               NaN
# air_034a3d5b40d5b1b1  14.828685  34.692337  135.472229          7.153846
# ...                         ...        ...         ...               ...
# air_fea5dc9594450608  14.485401  34.710895  137.725940          5.227273
# air_fee8dcf4d619598e  26.027778  34.695124  135.197853          5.000000
# air_fef9ccb3ba0da2f7   9.620408  34.815149  134.685353               NaN
# air_ffcc2d5087e1b476  20.242798  35.658068  139.751599               NaN
# air_fff68b929994bfbd   5.089219  35.708146  139.666288               NaN
#
#                       holiday_flg
# air_store_id
# air_00a91d42b08b08d9     0.004310
# air_0164b9927d20bcc3     0.033557
# air_0241aa3964b7f861     0.042929
# air_0328696196e46f18     0.051724
# air_034a3d5b40d5b1b1     0.059761
# ...                           ...
# air_fea5dc9594450608     0.036496
# air_fee8dcf4d619598e     0.059028
# air_fef9ccb3ba0da2f7     0.061224
# air_ffcc2d5087e1b476     0.020576
# air_fff68b929994bfbd     0.044610
#
# [829 rows x 5 columns]

# %%
#group by multiple columns
df_final.groupby(['air_store_id', 'day_of_week']).mean()
# Out:
#                                    visitors   latitude   longitude  \
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday       36.500000  35.694003  139.753595
#                      Monday       22.457143  35.694003  139.753595
#                      Saturday     14.973684  35.694003  139.753595
#                      Sunday        2.000000  35.694003  139.753595
#                      Thursday     29.868421  35.694003  139.753595
# ...                                     ...        ...         ...
# air_fff68b929994bfbd Saturday      7.439024  35.708146  139.666288
#                      Sunday        4.000000  35.708146  139.666288
#                      Thursday      4.707317  35.708146  139.666288
#                      Tuesday       4.526316  35.708146  139.666288
#                      Wednesday     4.634146  35.708146  139.666288
#
#                                   reserve_visitors  holiday_flg
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday                    2.0     0.000000
#                      Monday                    5.5     0.028571
#                      Saturday                  5.5     0.000000
#                      Sunday                    NaN     0.000000
#                      Thursday                 12.0     0.000000
# ...                                            ...          ...
# air_fff68b929994bfbd Saturday                  NaN     0.048780
#                      Sunday                    NaN     0.000000
#                      Thursday                  NaN     0.097561
#                      Tuesday                   NaN     0.026316
#                      Wednesday                 NaN     0.000000
#
# [5741 rows x 5 columns]

# %%
# with group by- the group bys become the index
df_final.groupby(['air_store_id', 'day_of_week']).mean().index
# Out:
# MultiIndex([('air_00a91d42b08b08d9',    'Friday'),
#             ('air_00a91d42b08b08d9',    'Monday'),
#             ('air_00a91d42b08b08d9',  'Saturday'),
#             ('air_00a91d42b08b08d9',    'Sunday'),
#             ('air_00a91d42b08b08d9',  'Thursday'),
#             ('air_00a91d42b08b08d9',   'Tuesday'),
#             ('air_00a91d42b08b08d9', 'Wednesday'),
#             ('air_0164b9927d20bcc3',    'Friday'),
#             ('air_0164b9927d20bcc3',    'Monday'),
#             ('air_0164b9927d20bcc3',  'Saturday'),
#             ...
#             ('air_ffcc2d5087e1b476',  'Thursday'),
#             ('air_ffcc2d5087e1b476',   'Tuesday'),
#             ('air_ffcc2d5087e1b476', 'Wednesday'),
#             ('air_fff68b929994bfbd',    'Friday'),
#             ('air_fff68b929994bfbd',    'Monday'),
#             ('air_fff68b929994bfbd',  'Saturday'),
#             ('air_fff68b929994bfbd',    'Sunday'),
#             ('air_fff68b929994bfbd',  'Thursday'),
#             ('air_fff68b929994bfbd',   'Tuesday'),
#             ('air_fff68b929994bfbd', 'Wednesday')],
#            names=['air_store_id', 'day_of_week'], length=5741)

# %%
# with group by- the group bys become the index- to sort by index do this
df_final.groupby(['air_store_id', 'day_of_week']).mean().sort_index(level = [0, 1])
# Out:
#                                    visitors   latitude   longitude  \
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday       36.500000  35.694003  139.753595
#                      Monday       22.457143  35.694003  139.753595
#                      Saturday     14.973684  35.694003  139.753595
#                      Sunday        2.000000  35.694003  139.753595
#                      Thursday     29.868421  35.694003  139.753595
# ...                                     ...        ...         ...
# air_fff68b929994bfbd Saturday      7.439024  35.708146  139.666288
#                      Sunday        4.000000  35.708146  139.666288
#                      Thursday      4.707317  35.708146  139.666288
#                      Tuesday       4.526316  35.708146  139.666288
#                      Wednesday     4.634146  35.708146  139.666288
#
#                                   reserve_visitors  holiday_flg
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday                    2.0     0.000000
#                      Monday                    5.5     0.028571
#                      Saturday                  5.5     0.000000
#                      Sunday                    NaN     0.000000
#                      Thursday                 12.0     0.000000
# ...                                            ...          ...
# air_fff68b929994bfbd Saturday                  NaN     0.048780
#                      Sunday                    NaN     0.000000
#                      Thursday                  NaN     0.097561
#                      Tuesday                   NaN     0.026316
#                      Wednesday                 NaN     0.000000
#
# [5741 rows x 5 columns]

# %%
# or just reset the index to make this back into a data frame
df_final.groupby(['air_store_id', 'day_of_week']).mean().reset_index()
# Out:
#               air_store_id day_of_week   visitors   latitude   longitude  \
# 0     air_00a91d42b08b08d9      Friday  36.500000  35.694003  139.753595
# 1     air_00a91d42b08b08d9      Monday  22.457143  35.694003  139.753595
# 2     air_00a91d42b08b08d9    Saturday  14.973684  35.694003  139.753595
# 3     air_00a91d42b08b08d9      Sunday   2.000000  35.694003  139.753595
# 4     air_00a91d42b08b08d9    Thursday  29.868421  35.694003  139.753595
# ...                    ...         ...        ...        ...         ...
# 5736  air_fff68b929994bfbd    Saturday   7.439024  35.708146  139.666288
# 5737  air_fff68b929994bfbd      Sunday   4.000000  35.708146  139.666288
# 5738  air_fff68b929994bfbd    Thursday   4.707317  35.708146  139.666288
# 5739  air_fff68b929994bfbd     Tuesday   4.526316  35.708146  139.666288
# 5740  air_fff68b929994bfbd   Wednesday   4.634146  35.708146  139.666288
#
#       reserve_visitors  holiday_flg
# 0                  2.0     0.000000
# 1                  5.5     0.028571
# 2                  5.5     0.000000
# 3                  NaN     0.000000
# 4                 12.0     0.000000
# ...                ...          ...
# 5736               NaN     0.048780
# 5737               NaN     0.000000
# 5738               NaN     0.097561
# 5739               NaN     0.026316
# 5740               NaN     0.000000
#
# [5741 rows x 7 columns]

# %%
# some operations cannot be directly applied to a group by- isnull() is an example
df_final.isnull().sum()
# Out:
# air_store_id             0
# visit_date               0
# visitors                 0
# air_genre_name           0
# air_area_name            0
# latitude                 0
# longitude                0
# reserve_visitors    224044
# calendar_date            0
# day_of_week              0
# holiday_flg              0
# calendar                 0
# dtype: int64

# %%
# in these cases, you can use an apply statement:
# in this case, x refers to each of the unique groupings- or the storeid and day of week grouping
# think about the chain of operations you want to apply and then tack them on to the group by. 
# this allows you to apply complicated logic to different segments of data 

df_final.groupby(['air_store_id', 'day_of_week']).apply(lambda x: x.isnull().sum() )
# Out:
#                                   air_store_id  visit_date  visitors  \
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday                  0           0         0
#                      Monday                  0           0         0
#                      Saturday                0           0         0
#                      Sunday                  0           0         0
#                      Thursday                0           0         0
# ...                                        ...         ...       ...
# air_fff68b929994bfbd Saturday                0           0         0
#                      Sunday                  0           0         0
#                      Thursday                0           0         0
#                      Tuesday                 0           0         0
#                      Wednesday               0           0         0
#
#                                   air_genre_name  air_area_name  latitude  \
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday                    0              0         0
#                      Monday                    0              0         0
#                      Saturday                  0              0         0
#                      Sunday                    0              0         0
#                      Thursday                  0              0         0
# ...                                          ...            ...       ...
# air_fff68b929994bfbd Saturday                  0              0         0
#                      Sunday                    0              0         0
#                      Thursday                  0              0         0
#                      Tuesday                   0              0         0
#                      Wednesday                 0              0         0
#
#                                   longitude  reserve_visitors  calendar_date  \
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday               0                39              0
#                      Monday               0                33              0
#                      Saturday             0                36              0
#                      Sunday               0                 1              0
#                      Thursday             0                37              0
# ...                                     ...               ...            ...
# air_fff68b929994bfbd Saturday             0                41              0
#                      Sunday               0                30              0
#                      Thursday             0                41              0
#                      Tuesday              0                38              0
#                      Wednesday            0                41              0
#
#                                   day_of_week  holiday_flg  calendar
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday                 0            0         0
#                      Monday                 0            0         0
#                      Saturday               0            0         0
#                      Sunday                 0            0         0
#                      Thursday               0            0         0
# ...                                       ...          ...       ...
# air_fff68b929994bfbd Saturday               0            0         0
#                      Sunday                 0            0         0
#                      Thursday               0            0         0
#                      Tuesday                0            0         0
#                      Wednesday              0            0         0
#
# [5741 rows x 12 columns]

# %%
# sometimes, instead of a single stat, you might want to see multiple stats next to each other
# use agg and pass a list with functions
df_final.groupby('air_store_id')['reserve_visitors'].agg([np.mean, np.max, np.median])
# Out:
#                           mean  amax  median
# air_store_id
# air_00a91d42b08b08d9  5.833333  18.0     3.5
# air_0164b9927d20bcc3  6.256410  26.0     5.0
# air_0241aa3964b7f861       NaN   NaN     NaN
# air_0328696196e46f18       NaN   NaN     NaN
# air_034a3d5b40d5b1b1  7.153846  50.0     3.0
# ...                        ...   ...     ...
# air_fea5dc9594450608  5.227273  15.0     4.0
# air_fee8dcf4d619598e  5.000000   5.0     5.0
# air_fef9ccb3ba0da2f7       NaN   NaN     NaN
# air_ffcc2d5087e1b476       NaN   NaN     NaN
# air_fff68b929994bfbd       NaN   NaN     NaN
#
# [829 rows x 3 columns]

# %% [markdown]
# **Question 1:** What restaurant had the highest total amount of visitors throughout the dataset?

# %%
# your answer here

df_final.groupby('air_area_name')['visitors'].sum().sort_values(ascending=False)

# Fukuoka-ken Fukuoka-shi Daimyō had the most visitors
# Out:
# air_area_name
# Fukuoka-ken Fukuoka-shi Daimyō           408708
# Tōkyō-to Shibuya-ku Shibuya              366744
# Tōkyō-to Minato-ku Shibakōen             288180
# Tōkyō-to Shinjuku-ku Kabukichō           244996
# Tōkyō-to Chūō-ku Tsukiji                 186263
#                                           ...
# Ōsaka-fu Neyagawa-shi Honmachi             5424
# Fukuoka-ken Kitakyūshū-shi Konyamachi      5254
# Tōkyō-to Shibuya-ku Higashi                4133
# Hokkaidō Katō-gun Motomachi                3731
# Tōkyō-to Setagaya-ku Kitazawa              2166
# Name: visitors, Length: 103, dtype: int64

# %% [markdown]
# **Question 2:** What was the average attendance for holidays & non-holidays for all restaurants?

# %%
# your answer here
df_final.groupby('holiday_flg')['visitors'].mean()
# Out:
# holiday_flg
# 0    20.828064
# 1    23.703327
# Name: visitors, dtype: float64

# %% [markdown]
# **Question 3:** Can you grab the first 15 rows of dates for each restaurant?  The last 15 rows? (**Hint:** Use the `apply` method for this)

# %%
# your answer here
df_final.groupby('air_store_id').apply(lambda x: x.head(15)) 

# or this
df.groupby('id').apply(lambda x: x.iloc[:15])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kz/klxfgxt54zg3ld3hw3501lf80000gp/T/ipykernel_20133/4104410828.py in <module>
#       3
#       4 # or this
# ----> 5 df.groupby('id').apply(lambda x: x.iloc[:15])
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Question 4:** Grab the quarterly sales for each individual restaurant within our dataset

# %%
# your answer here
df_final['quarter']=df_final['visit_date'].dt.quarter

# %%
df_final.head()

# %%
df_final.groupby('quarter')['visitors'].sum()

# %% [markdown]
# **Question 5:** What restaurant had the highest amount of total reservations?

# %%
# your answer here
df_final.groupby('air_area_name')['reserve_visitors'].sum().sort_values(ascending=False)

# %% [markdown]
# **Question 6:** What is the total number of missing entries for each restaurant?

# %%
# # your answer here

df_final.groupby('air_area_name').apply(lambda x: x.isnull()).sum()

# %% [markdown]
# **Question 7:**  Create two variables, `train` and `test`.  Make `train` a dataset that contains all but the **last 15 rows** for each restaurant, ordered chronologically.  Make `test` the last 15 rows for each restaurant.

# %%
# your answer here
# sort the values first

df_final.sort_values(by=['air_store_id', 'calendar_date'], inplace=True)

# %%
len(df_final) - 15

# %%
train = df_final.groupby('air_store_id').apply(lambda x: x.iloc[:-15])

test = df_final.groupby('air_store_id').apply(lambda x: x.iloc[-15:])

# %% [markdown]
# ### Grouping & Merging
#
# In this section of the lab, we are going to create different types of summary statistics -- where the rows for an individual sample can be compared with a larger group statistic.
#
# **Bonus:** If you want to make this a little bit more effective, instead of using the entire `df`, try using a grouping from the `train` variable you just created, and use the grouping's values to populate both the training and test sets.

# %% [markdown]
# Use the technique discussed in class to create columns for the following stats:

# %% [markdown]
# **Question 1:** Create columns that list the average, median and standard deviation of visitors for each restaurant

# %%
# your answer here

df_final.groupby('air_store_id')['visitors'].agg([np.mean, np.median, np.std])


# .agg([np.mean, np.median, np.stdev])
# ({'A' : ['sum', 'min'], 'B' : ['min', 'max']})
# Out:
#                            mean  median        std
# air_store_id
# air_00a91d42b08b08d9  26.081897    26.0  12.435364
# air_0164b9927d20bcc3   9.248322     8.0   6.348980
# air_0241aa3964b7f861   9.896465     9.0   6.214877
# air_0328696196e46f18   7.939655     6.0   6.733807
# air_034a3d5b40d5b1b1  14.828685    12.0  13.154107
# ...                         ...     ...        ...
# air_fea5dc9594450608  14.485401    13.0   8.528006
# air_fee8dcf4d619598e  26.027778    27.0   9.799697
# air_fef9ccb3ba0da2f7   9.620408     8.0   5.387333
# air_ffcc2d5087e1b476  20.242798    19.0  10.917927
# air_fff68b929994bfbd   5.089219     5.0   3.177497
#
# [829 rows x 3 columns]

# %% [markdown]
# **Question 2:** Create a column that lists the average and median sales amount for each restaurant on a particular day of the week.

# %%
# your answer here
df_final.groupby(['air_store_id', 'day_of_week'])['visitors'].agg([np.mean, np.median, np.std])
# Out:
#                                        mean  median        std
# air_store_id         day_of_week
# air_00a91d42b08b08d9 Friday       36.500000    35.5   9.021342
#                      Monday       22.457143    19.0   9.425693
#                      Saturday     14.973684    11.0  16.793639
#                      Sunday        2.000000     2.0        NaN
#                      Thursday     29.868421    30.0   7.143968
# ...                                     ...     ...        ...
# air_fff68b929994bfbd Saturday      7.439024     7.0   3.521710
#                      Sunday        4.000000     3.5   2.477485
#                      Thursday      4.707317     4.0   2.786072
#                      Tuesday       4.526316     4.0   2.554665
#                      Wednesday     4.634146     4.0   2.981242
#
# [5741 rows x 3 columns]

# %% [markdown]
# **Question 3:** Create columns that display the average and median sales amount for each genre in each city on each day of the week.  Create a column called `city` that captures the first value of `area` in order to this.  Values should be `Tokyo`, `Hiroshima`, etc.  **Hint:** You should use the `str` attribute combined with `split` in order to do this.

# %%
# your answer here
df_final['City']= df_final['air_area_name'].str.split(expand=True)[0]

# %%
df_final.head()
# Out:
#            air_store_id visit_date  visitors air_genre_name  \
# 0  air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6     Dining bar
#
#                   air_area_name   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#   calendar_date day_of_week  holiday_flg   calendar      City
# 0    2016-01-13   Wednesday            0 2016-01-13  Tōkyō-to
# 1    2016-01-14    Thursday            0 2016-01-14  Tōkyō-to
# 2    2016-01-15      Friday            0 2016-01-15  Tōkyō-to
# 3    2016-01-16    Saturday            0 2016-01-16  Tōkyō-to
# 4    2016-01-18      Monday            0 2016-01-18  Tōkyō-to

# %%
df_final.groupby(['air_genre_name', 'City', 'day_of_week'])['visitors'].agg([np.mean, np.median, np.std])
# Out:
#                                                 mean  median        std
# air_genre_name       City     day_of_week
# Asian                Tōkyō-to Friday       38.829545    38.0  14.999787
#                               Monday       33.964286    32.0  17.859860
#                               Saturday     44.684783    49.0  17.385057
#                               Sunday       47.533333    51.0  23.802181
#                               Thursday     33.357143    33.5  16.454266
# ...                                              ...     ...        ...
# Yakiniku/Korean food Ōsaka-fu Saturday     15.225275    14.0   9.543087
#                               Sunday       19.165563    18.0  12.452272
#                               Thursday     12.805556    10.5   8.244922
#                               Tuesday      12.957746    10.0  10.621050
#                               Wednesday    15.162011    13.0   9.761280
#
# [476 rows x 3 columns]
