# %%
import pandas as pd
import numpy as np

# %%
path = '/Users/hannah.westberg/Projects/GA-DS-Repo/ClassMaterial/Unit1/data/master.csv'

# %%
# parse dates can be used to load dates as date type. must provide a list
df = pd.read_csv(path, parse_dates=['visit_date'])

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN

# %%
#select on condition- but tack on a method (specify the column for the mean)
df[df['visitors'] >= 25]['visitors'].mean()
# Out:
# 39.62192423491288

# %% [markdown]
# # Creating new columns in Pandas

# %%
df['newCol'] = 1

# %%
df['randNumbers'] = np.random.normal(size=252108)

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    newCol  randNumbers
# 0       1     0.337012
# ...

# %%
# common ways to create data:
np.where
np.select()
df.apply()

# %%
# if you have a single condition needed to transform data. np.where is a great answers
# example- create a new column to categorize days as being busy or not busy, if there are more 
# than 30 people

df['busy_fl'] = np.where(df['visitors'] >=30, 'busy', 'not busy')

# %%
# numpy select- fancier version of the where method.
# create your conditions here

(df['busy_fl'] == 'busy')& (df['randNumbers']<= 0)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252103    False
# 252104    False
# 252105    False
# 252106     True
# 252107    False
# Length: 252108, dtype: bool

# %%
# this is essentially a case statement in SQL or an if/else in regular python
# this is much faster than other ways
# these are essentially the queries
conditions = [(df['busy_fl'] == 'busy')& (df['randNumbers']<= 0),
             (df['busy_fl'] == 'busy')& (df['randNumbers']> 0),
             (df['busy_fl'] == 'not busy')& (df['randNumbers']<= 0),
             (df['busy_fl'] == 'not busy')& (df['randNumbers']>0 )]

# these are the results
result = ['a', 'b', 'c', 'd']

df['newCol2']= np.select(conditions, result, 'Other')

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    newCol  randNumbers   busy_fl newCol2
# ...

# %% [markdown]
# # Lab 3

# %% [markdown]
# ### Section I: Creating Data Out of Your Existing Columns
#
# Go ahead and create the following columns in your dataset.

# %% [markdown]
# **Column 1:**
#
#   - **Column Name:** Weekend
#   - **Values:** `True` if `day_of_week` is either Friday or Saturday, `False` if not

# %%
df['busy_fl'] = np.where(df['visitors'] >=30, 'busy', 'not busy')

df['Weekend']= np.where((df['day_of_week'] == 'Friday') | (df['day_of_week'] == 'Saturday') , True, False)

# %%
# other option for the selection part, using isin:
df.day_of_week.isin(['Saturday', 'Sunday'])
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 252103    False
# 252104     True
# 252105     True
# 252106    False
# 252107     True
# Name: day_of_week, Length: 252108, dtype: bool

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    newCol  randNumbers   busy_fl newCol2  Weekend
# ...

# %% [markdown]
# **Column 2:**
#
#  - **Column Name:** Reservation Activity
#  - **Values:**
#    - `Low` if `reserve_visitors` is in the bottom .25 percentile
#    - `Medium` if `reserve_visitors` is in the middle .50 percentile
#    - `High`if `reserve_visitors` is in the top .25 percentile
#
# **Hint:** Use the `quantile` method to get this value

# %%
conditions = [
    df['reserve_visitors'] < df['reserve_visitores'].quantile(.25),
    df['reserve_visitors'].between(df['reserve_visitors'].quantile(.25),df['reserve_visitors'].quantile(.75))
    df['reserve_visitors'] > df['reserve_visitors'].quantile(.75)
    
]

# these are the results
result = ['Low', 'Medium', 'High']

df['reservation_activity']= np.select(conditions, result, 'Other')
# Out:
#   File "/var/folders/kz/klxfgxt54zg3ld3hw3501lf80000gp/T/ipykernel_36132/3865747706.py", line 4
#     df['reserve_visitors'] > df['reserve_visitors'].quantile(.75)
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
# Empty DataFrame
# Columns: [id, visit_date, visitors, day_of_week, holiday, genre, area, latitude, longitude, reserve_visitors, newCol, randNumbers, busy_fl, newCol2, Weekend, quartile, reservation_activity]
# Index: []
